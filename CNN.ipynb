# %% [markdown]
# - Classify images ino 10 categories:
# airplane, car, bird, cat, deer, dog, frog, horse, ship, truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# Each image is 32x32x3
# - 32 = width
# - 32 = width
# - 3 = RGB(Red,Blue,Green)
# Labels are number from 0to 9

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
model = models.Sequential([
    #Convulutional Layer 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    #Convulutional Layer 2
    layers.Conv2D(64, (3, 3), activation='relu'),   
    layers.MaxPooling2D((2, 2)),
    #Flatten and Dense Layers
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\HP\miniconda3\envs\tf\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.4635 - loss: 1.4988
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.5951 - loss: 1.1511
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.6469 - loss: 1.0127
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.6750 - loss: 0.9350
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6955 - loss: 0.8701
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.7164 - loss: 0.8167
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.7325 - loss: 0.7686
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.7470 - loss: 0.7215
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.7618 - loss: 0.6820
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7723 - loss: 0.6487

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {accuracy}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7081 - loss: 0.9053
# Test accuracy: 0.7081000208854675

# %% [markdown]
# UPGRADE 1: Make CNN Slightly Deeper
#
# CIFAR-10 images are complex:
#
# colors
#
# textures
#
# overlapping objects
#
# 2 Convulution layers are not enough to capture this.
#
# So we:
#
# add one more Convulutional layer
#
# increase feature extraction depth

# %%
model = models.Sequential([
    #Block 1 
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),

    # Block 2
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),

    # Block 3 (NEW)
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# UPGRADE 2: Add Batch Normalization During Training:
#
# Feature values keep changing
#
# Learning becomes unstable
#
# Batch Normalization:
#
# Keeps values in a stable range
#
# Allows faster and deeper learning
#
# Reduces vanishing/exploding gradients
#
# Almost all modern CNN use it

# %%
model = models.Sequential([
    #Block 1 
    layers.Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    # Block 2
    layers.Conv2D(64, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    # Block 3 (NEW)
    layers.Conv2D(128, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# UPGRADE 3: Add Dropout + Train longer (Generalization)
#
# CNN is powerfyl -> risk of overfitting
#
# Dropout:
#
# Forces model to not depend on single neurons
#
# Improves test accuracy
#
# Also:
#
# CIFAR-10 needs more epochs

# %%
model = models.Sequential([    
    #Block 1 
    layers.Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    # Block 2
    layers.Conv2D(64, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    # Block 3 (NEW)
    layers.Conv2D(128, (3, 3), padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\HP\miniconda3\envs\tf\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 78ms/step - accuracy: 0.2844 - loss: 1.8939 - val_accuracy: 0.4756 - val_loss: 1.4599
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.3731 - loss: 1.6143 - val_accuracy: 0.4646 - val_loss: 1.4347
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4135 - loss: 1.5075 - val_accuracy: 0.3578 - val_loss: 1.9170
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.4384 - loss: 1.4473 - val_accuracy: 0.5349 - val_loss: 1.2912
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.4673 - loss: 1.3797 - val_accuracy: 0.6222 - val_loss: 1.1264
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.4943 - loss: 1.3234 - val_accuracy: 0.5299 - val_loss: 1.2951
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 83ms/step - accuracy: 0.5206 - loss: 1.2558 - val_accuracy: 0.5655 - val_loss: 1.1782
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 84ms/step - accuracy: 0.5337 - loss: 1.2137 - val_accuracy: 0.6648 - val_loss: 0.9667
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.5567 - loss: 1.1622 - val_accuracy: 0.5748 - val_loss: 1.4030
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.5696 - loss: 1.1323 - val_accuracy: 0.5983 - val_loss: 1.1718
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.5791 - loss: 1.1038 - val_accuracy: 0.6859 - val_loss: 0.9119
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.5923 - loss: 1.0591 - val_accuracy: 0.6726 - val_loss: 0.9202
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.6214 - loss: 1.0023 - val_accuracy: 0.6832 - val_loss: 0.9361
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.6463 - loss: 0.9468 - val_accuracy: 0.7050 - val_loss: 0.8719
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 77ms/step - accuracy: 0.6601 - loss: 0.9110 - val_accuracy: 0.7019 - val_loss: 0.9365
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.6757 - loss: 0.8650 - val_accuracy: 0.6940 - val_loss: 0.9339
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 216s 276ms/step - accuracy: 0.6995 - loss: 0.8175 - val_accuracy: 0.6533 - val_loss: 1.1302
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.7095 - loss: 0.7859 - val_accuracy: 0.6875 - val_loss: 1.0971
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.7174 - loss: 0.7601 - val_accuracy: 0.6994 - val_loss: 0.9756
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.7307 - loss: 0.7283 - val_accuracy: 0.7068 - val_loss: 0.9633
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.7386 - loss: 0.7061 - val_accuracy: 0.7194 - val_loss: 0.8473
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.7471 - loss: 0.6798 - val_accuracy: 0.7183 - val_loss: 0.9683
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.7606 - loss: 0.6456 - val_accuracy: 0.7451 - val_loss: 0.7948
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.7676 - loss: 0.6249 - val_accuracy: 0.6946 - val_loss: 1.0840
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 189s 242ms/step - accuracy: 0.7769 - loss: 0.6076 - val_accuracy: 0.7296 - val_loss: 0.8614
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.7820 - loss: 0.5867 - val_accuracy: 0.7160 - val_loss: 0.9882
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 81ms/step - accuracy: 0.7920 - loss: 0.5649 - val_accuracy: 0.7016 - val_loss: 1.1223
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.7959 - loss: 0.5485 - val_accuracy: 0.7434 - val_loss: 0.8115
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.8028 - loss: 0.5295 - val_accuracy: 0.7365 - val_loss: 1.0053
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 84ms/step - accuracy: 0.8084 - loss: 0.5154 - val_accuracy: 0.7426 - val_loss: 1.0673

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {accuracy}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7426 - loss: 1.0673
# Test accuracy: 0.7426000237464905
